# %% [markdown]
# # *Stock prediction *
#
#
# # *Bharat intern task 1
#
#
# # Hitendra pardeshi *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('NFLX.csv')
df.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2018-02-05  262.000000  267.899994  250.029999  254.259995  254.259995
# 1  2018-02-06  247.699997  266.700012  245.000000  265.720001  265.720001
# 2  2018-02-07  266.579987  272.450012  264.329987  264.559998  264.559998
# 3  2018-02-08  267.079987  267.619995  250.000000  250.100006  250.100006
# 4  2018-02-09  253.850006  255.800003  236.110001  249.470001  249.470001
# 5  2018-02-12  252.139999  259.149994  249.000000  257.950012  257.950012
# 6  2018-02-13  257.290009  261.410004  254.699997  258.269989  258.269989
# 7  2018-02-14  260.470001  269.880005  260.329987  266.000000  266.000000
# 8  2018-02-15  270.029999  280.500000  267.630005  280.269989  280.269989
# 9  2018-02-16  278.730011  281.959991  275.690002  278.519989  278.519989
#
#      Volume
# 0  11896100
# 1  12595800
# 2   8981500
# 3   9306700
# 4  16906900
# 5   8534900
# 6   6855200
# 7  10972000
# 8  10759700
# 9   8312400

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1009, 7)

# %%
df.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1009.000000  1009.000000  1009.000000  1009.000000  1009.000000
# mean    419.059673   425.320703   412.374044   419.000733   419.000733
# std     108.537532   109.262960   107.555867   108.289999   108.289999
# min     233.919998   250.649994   231.229996   233.880005   233.880005
# 25%     331.489990   336.299988   326.000000   331.619995   331.619995
# 50%     377.769989   383.010010   370.880005   378.670013   378.670013
# 75%     509.130005   515.630005   502.529999   509.079987   509.079987
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  1.009000e+03
# mean   7.570685e+06
# std    5.465535e+06
# min    1.144000e+06
# 25%    4.091900e+06
# 50%    5.934500e+06
# 75%    9.322400e+06
# max    5.890430e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1009 non-null   object
#  1   Open       1009 non-null   float64
#  2   High       1009 non-null   float64
#  3   Low        1009 non-null   float64
#  4   Close      1009 non-null   float64
#  5   Adj Close  1009 non-null   float64
#  6   Volume     1009 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 55.3+ KB

# %%
df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
def preprocess_data(data):
    scaler = MinMaxScaler(feature_range=(0, 1))
    scaled_data = scaler.fit_transform(data.reshape(-1, 1))
    return scaled_data

# %%
closing_prices = df['Close'].values
scaled_closing_prices = preprocess_data(closing_prices)
n_steps = 60

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['Open'],label='Open',color='blue')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['Close'],label='Close',color='orange')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
X, y = [], []
for i in range(len(scaled_closing_prices) - n_steps):
    X.append(scaled_closing_prices[i:i + n_steps])
    y.append(scaled_closing_prices[i + n_steps])
X, y = np.array(X), np.array(y)

# %%
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test), verbose=1)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 62ms/step - loss: 0.1057 - val_loss: 0.1595
# Epoch 2/100
# 24/24 [==============================] - 1s 36ms/step - loss: 0.0149 - val_loss: 0.0348
# Epoch 3/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0054 - val_loss: 0.0155
# Epoch 4/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0026 - val_loss: 0.1063
# Epoch 5/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0022 - val_loss: 0.0405
# Epoch 6/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0021 - val_loss: 0.0325
# Epoch 7/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0020 - val_loss: 0.0188
# Epoch 8/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0019 - val_loss: 0.0111
# Epoch 9/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0019 - val_loss: 0.0058
# Epoch 10/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0018 - val_loss: 0.0057
# Epoch 11/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0017 - val_loss: 0.0049
# Epoch 12/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0016 - val_loss: 0.0062
# Epoch 13/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0016 - val_loss: 0.0048
# Epoch 14/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0015 - val_loss: 0.0033
# Epoch 15/100
# 24/24 [==============================] - 1s 29ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 16/100
# 24/24 [==============================] - 1s 42ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 17/100
# 24/24 [==============================] - 1s 49ms/step - loss: 0.0014 - val_loss: 0.0031
# Epoch 18/100
# 24/24 [==============================] - 1s 46ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 19/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0013 - val_loss: 0.0027
# Epoch 20/100
# 24/24 [==============================] - 1s 30ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 21/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0013 - val_loss: 0.0028
# Epoch 22/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 23/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 24/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0012 - val_loss: 0.0023
# Epoch 25/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 26/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0011 - val_loss: 0.0021
# Epoch 27/100
# 24/24 [==============================] - 1s 31ms/step - loss: 0.0010 - val_loss: 0.0021
# Epoch 28/100
# 24/24 [==============================] - 1s 32ms/step - loss: 9.8478e-04 - val_loss: 0.0024
# Epoch 29/100
# 24/24 [==============================] - 1s 31ms/step - loss: 9.9307e-04 - val_loss: 0.0020
# Epoch 30/100
# 24/24 [==============================] - 1s 31ms/step - loss: 9.3166e-04 - val_loss: 0.0024
# Epoch 31/100
# 24/24 [==============================] - 1s 32ms/step - loss: 9.0621e-04 - val_loss: 0.0021
# Epoch 32/100
# 24/24 [==============================] - 1s 44ms/step - loss: 9.2095e-04 - val_loss: 0.0020
# Epoch 33/100
# 24/24 [==============================] - 1s 47ms/step - loss: 8.7683e-04 - val_loss: 0.0019
# Epoch 34/100
# 24/24 [==============================] - 1s 49ms/step - loss: 8.5991e-04 - val_loss: 0.0024
# Epoch 35/100
# 24/24 [==============================] - 1s 31ms/step - loss: 8.3944e-04 - val_loss: 0.0019
# Epoch 36/100
# 24/24 [==============================] - 1s 31ms/step - loss: 7.9944e-04 - val_loss: 0.0017
# Epoch 37/100
# 24/24 [==============================] - 1s 30ms/step - loss: 8.5407e-04 - val_loss: 0.0020
# Epoch 38/100
# 24/24 [==============================] - 1s 31ms/step - loss: 8.1237e-04 - val_loss: 0.0017
# Epoch 39/100
# 24/24 [==============================] - 1s 49ms/step - loss: 7.7262e-04 - val_loss: 0.0016
# Epoch 40/100
# 24/24 [==============================] - 1s 31ms/step - loss: 7.5193e-04 - val_loss: 0.0015
# Epoch 41/100
# 24/24 [==============================] - 1s 30ms/step - loss: 7.3806e-04 - val_loss: 0.0015
# Epoch 42/100
# 24/24 [==============================] - 1s 31ms/step - loss: 7.2186e-04 - val_loss: 0.0016
# Epoch 43/100
# 24/24 [==============================] - 1s 32ms/step - loss: 7.1683e-04 - val_loss: 0.0014
# Epoch 44/100
# 24/24 [==============================] - 1s 32ms/step - loss: 6.7665e-04 - val_loss: 0.0015
# Epoch 45/100
# 24/24 [==============================] - 1s 40ms/step - loss: 6.7369e-04 - val_loss: 0.0016
# Epoch 46/100
# 24/24 [==============================] - 2s 70ms/step - loss: 6.7584e-04 - val_loss: 0.0014
# Epoch 47/100
# 24/24 [==============================] - 2s 96ms/step - loss: 6.8691e-04 - val_loss: 0.0016
# Epoch 48/100
# 24/24 [==============================] - 2s 77ms/step - loss: 6.4142e-04 - val_loss: 0.0014
# Epoch 49/100
# 24/24 [==============================] - 2s 65ms/step - loss: 6.7584e-04 - val_loss: 0.0014
# Epoch 50/100
# 24/24 [==============================] - 1s 59ms/step - loss: 6.7061e-04 - val_loss: 0.0013
# Epoch 51/100
# 24/24 [==============================] - 1s 62ms/step - loss: 6.9121e-04 - val_loss: 0.0014
# Epoch 52/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.5473e-04 - val_loss: 0.0014
# Epoch 53/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.2709e-04 - val_loss: 0.0013
# Epoch 54/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.2172e-04 - val_loss: 0.0012
# Epoch 55/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.0352e-04 - val_loss: 0.0012
# Epoch 56/100
# 24/24 [==============================] - 1s 32ms/step - loss: 5.9745e-04 - val_loss: 0.0015
# Epoch 57/100
# 24/24 [==============================] - 1s 43ms/step - loss: 6.5721e-04 - val_loss: 0.0014
# Epoch 58/100
# 24/24 [==============================] - 1s 49ms/step - loss: 6.4306e-04 - val_loss: 0.0014
# Epoch 59/100
# 24/24 [==============================] - 1s 48ms/step - loss: 6.2405e-04 - val_loss: 0.0013
# Epoch 60/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.0405e-04 - val_loss: 0.0017
# Epoch 61/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.2814e-04 - val_loss: 0.0013
# Epoch 62/100
# 24/24 [==============================] - 1s 30ms/step - loss: 7.0808e-04 - val_loss: 0.0013
# Epoch 63/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.5209e-04 - val_loss: 0.0012
# Epoch 64/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.3368e-04 - val_loss: 0.0012
# Epoch 65/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.1774e-04 - val_loss: 0.0014
# Epoch 66/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.9072e-04 - val_loss: 0.0022
# Epoch 67/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.5648e-04 - val_loss: 0.0013
# Epoch 68/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.8114e-04 - val_loss: 0.0013
# Epoch 69/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.8068e-04 - val_loss: 0.0012
# Epoch 70/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.8974e-04 - val_loss: 0.0012
# Epoch 71/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.2137e-04 - val_loss: 0.0013
# Epoch 72/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.0301e-04 - val_loss: 0.0012
# Epoch 73/100
# 24/24 [==============================] - 1s 35ms/step - loss: 5.7751e-04 - val_loss: 0.0013
# Epoch 74/100
# 24/24 [==============================] - 1s 46ms/step - loss: 5.7171e-04 - val_loss: 0.0013
# Epoch 75/100
# 24/24 [==============================] - 1s 49ms/step - loss: 5.6245e-04 - val_loss: 0.0012
# Epoch 76/100
# 24/24 [==============================] - 1s 34ms/step - loss: 6.0104e-04 - val_loss: 0.0012
# Epoch 77/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.7406e-04 - val_loss: 0.0016
# Epoch 78/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.8164e-04 - val_loss: 0.0013
# Epoch 79/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.6074e-04 - val_loss: 0.0012
# Epoch 80/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.9532e-04 - val_loss: 0.0013
# Epoch 81/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.9355e-04 - val_loss: 0.0013
# Epoch 82/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.7931e-04 - val_loss: 0.0012
# Epoch 83/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.7227e-04 - val_loss: 0.0012
# Epoch 84/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.7171e-04 - val_loss: 0.0012
# Epoch 85/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.1197e-04 - val_loss: 0.0012
# Epoch 86/100
# 24/24 [==============================] - 1s 29ms/step - loss: 6.1010e-04 - val_loss: 0.0013
# Epoch 87/100
# 24/24 [==============================] - 1s 29ms/step - loss: 6.5329e-04 - val_loss: 0.0017
# Epoch 88/100
# 24/24 [==============================] - 1s 30ms/step - loss: 6.2224e-04 - val_loss: 0.0016
# Epoch 89/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.3478e-04 - val_loss: 0.0014
# Epoch 90/100
# 24/24 [==============================] - 1s 46ms/step - loss: 5.7687e-04 - val_loss: 0.0016
# Epoch 91/100
# 24/24 [==============================] - 1s 49ms/step - loss: 5.6822e-04 - val_loss: 0.0012
# Epoch 92/100
# 24/24 [==============================] - 1s 42ms/step - loss: 5.7941e-04 - val_loss: 0.0013
# Epoch 93/100
# 24/24 [==============================] - 1s 32ms/step - loss: 5.6202e-04 - val_loss: 0.0012
# Epoch 94/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.4953e-04 - val_loss: 0.0012
# Epoch 95/100
# 24/24 [==============================] - 1s 32ms/step - loss: 5.5842e-04 - val_loss: 0.0012
# Epoch 96/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.6273e-04 - val_loss: 0.0014
# Epoch 97/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.4848e-04 - val_loss: 0.0014
# Epoch 98/100
# 24/24 [==============================] - 1s 30ms/step - loss: 5.7938e-04 - val_loss: 0.0021
# Epoch 99/100
# 24/24 [==============================] - 1s 31ms/step - loss: 6.3982e-04 - val_loss: 0.0014
# Epoch 100/100
# 24/24 [==============================] - 1s 31ms/step - loss: 5.7625e-04 - val_loss: 0.0013

# %%
plt.plot(history.history['loss'], label='Training Loss')

# %%
plt.plot(history.history['val_loss'], label='Validation Loss')

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.legend()
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler.fit(X_train.reshape(-1, 1))
# Out:
# MinMaxScaler()

# %%
test_predicted = model.predict(X_test)
# Out:
# 6/6 [==============================] - 0s 12ms/step

# %%
test_predicted_actual = scaler.inverse_transform(test_predicted)

# %%
y_test_actual = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual, label='Actual Stock Prices')
plt.plot(test_predicted_actual, label='Predicted Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.legend()
plt.show()

# %%
n_future_steps = 30
last_sequence = X_test[-1]
future_predictions = []
for _ in range(n_future_steps):
       last_sequence_reshaped = last_sequence.reshape(1, n_steps, 1)

# %%
next_step_prediction = model.predict(last_sequence_reshaped)
future_predictions.append(next_step_prediction[0, 0])
last_sequence = np.append(last_sequence[1:], next_step_prediction)
# Out:
# 1/1 [==============================] - 0s 24ms/step

# %%
future_predictions_actual = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test_actual[-n_future_steps:], label='Actual Stock Prices')
plt.plot(future_predictions_actual, label='Predicted Future Stock Prices')
plt.xlabel('Time')
plt.ylabel('Stock Prices')
plt.legend()
plt.show()
